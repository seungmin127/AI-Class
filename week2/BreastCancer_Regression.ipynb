# %% [markdown]
# **BreastCancer-Regression**

# %%
# 데이터 처리(pandas), 수치 계산(numpy), 구글 드라이브 연동을 위한 라이브러리 import
import pandas as pd
import numpy as np
from google.colab import drive

drive.mount('/content/drive') # 구글 드라이브를 Colab에 연결(마운트)

path = '/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# DataFrame으로 읽기
df = pd.read_csv(path, index_col=0)
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# label 열을 제외한 새로운 DataFrame 생성
df2=df.drop('label',axis=1)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
# 정답 데이터(y)로 worst compactness 열을 추출하고 값 확인
y=df2['worst compactness']
y.value_counts()
y
# Out:
# 0      0.66560
# 1      0.18660
# 2      0.42450
# 3      0.86630
# 4      0.20500
#         ...
# 564    0.21130
# 565    0.19220
# 566    0.30940
# 567    0.86810
# 568    0.06444
# Name: worst compactness, Length: 569, dtype: float64

# %%
# worst compactness 열을 제외한 입력 데이터(X)를 만들고 상위 5개 행 확인
X=df2.drop('worst compactness',axis=1)
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  fractal dimension error  worst radius  \
# ...

# %%
# 데이터를 학습용(train)과 테스트용(test)으로 나누기 (25%는 테스트 데이터)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %%
# 라이브러리 import
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
model = LinearRegression()       # 선형 회귀 모델 생성
model.fit(X_train, y_train)      # 학습 데이터로 모델 학습
ly_preds = model.predict(X_test) # 테스트 데이터로 예측값 생성

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))
# sklearn으로 MSE(평균제곱오차) 계산 및 출력

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)
# numpy를 이용해 MSE 계산하는 함수 정의

print('평균제곱근오차', mse_np(ly_preds, y_test))
# numpy로 계산한 MSE 출력

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    # 실제값과 예측값 차이를 제곱해서 모두 더함
    mean_square_error = sum_square_error / len(actual)
    # 전체 개수로 나눠 평균 계산
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.0004971870077830486
# 평균제곱근오차 0.0004971870077830486
# 평균제곱근오차 0.0004971870077830486

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.007111157241258742

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.0026207863474276907
