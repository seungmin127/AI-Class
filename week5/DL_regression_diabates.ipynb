# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# 데이터 불러오기
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#상관 관계 행렬
# 0.3 이상인 경우 상관관계가 있고, 0.7이상이면 아주 높음

df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#0값 처리
df[['Insulin','SkinThickness']] = df[['Insulin','SkinThickness']].replace(0, np.nan)
df = df.fillna(df.mean())

# %%
X = df.drop('BMI', axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6      148             72       35.00000  155.548223
# 1            1       85             66       29.00000  155.548223
# 2            8      183             64       29.15342  155.548223
# 3            1       89             66       23.00000   94.000000
# 4            0      137             40       35.00000  168.000000
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df['BMI']
y.head()
# Out:
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# Name: BMI, dtype: float64

# %%
#딥러닝 입력을 위해 Numpy로 변환
X = X.values

# %%
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
y
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# X 스케일링
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

# y 스케일링
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape,
# Out:
# ((614, 8), (614, 1), (154, 8), (154, 1))

# %%
#Defining the model

from keras.models import Sequential
from keras.optimizers import SGD,Adam
from keras.layers import Dense, Input, Dropout

model = Sequential([
    Input(shape=(8,)),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_35 (Dense)                │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 833 (3.25 KB)
#  Trainable params: 833 (3.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
N_EPOCHS = 100

history=model.fit(x=X_train, y=y_train, epochs=N_EPOCHS, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.1132 - mse: 1.1132 - val_loss: 0.9082 - val_mse: 0.9082
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9538 - mse: 0.9538 - val_loss: 0.8281 - val_mse: 0.8281
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8581 - mse: 0.8581 - val_loss: 0.7748 - val_mse: 0.7748
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7881 - mse: 0.7881 - val_loss: 0.7505 - val_mse: 0.7505
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7448 - mse: 0.7448 - val_loss: 0.7402 - val_mse: 0.7402
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7421 - mse: 0.7421 - val_loss: 0.7287 - val_mse: 0.7287
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7326 - mse: 0.7326 - val_loss: 0.7261 - val_mse: 0.7261
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6848 - mse: 0.6848 - val_loss: 0.7260 - val_mse: 0.7260
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6945 - mse: 0.6945 - val_loss: 0.7219 - val_mse: 0.7219
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6777 - mse: 0.6777 - val_loss: 0.7236 - val_mse: 0.7236
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5476 - mse: 0.5476 - val_loss: 0.7248 - val_mse: 0.7248
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5551 - mse: 0.5551 - val_loss: 0.7177 - val_mse: 0.7177
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5427 - mse: 0.5427 - val_loss: 0.7214 - val_mse: 0.7214
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5601 - mse: 0.5601 - val_loss: 0.7150 - val_mse: 0.7150
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5179 - mse: 0.5179 - val_loss: 0.7161 - val_mse: 0.7161
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5530 - mse: 0.5530 - val_loss: 0.7135 - val_mse: 0.7135
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5524 - mse: 0.5524 - val_loss: 0.7082 - val_mse: 0.7082
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5812 - mse: 0.5812 - val_loss: 0.7066 - val_mse: 0.7066
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5402 - mse: 0.5402 - val_loss: 0.7108 - val_mse: 0.7108
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5289 - mse: 0.5289 - val_loss: 0.7099 - val_mse: 0.7099
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5726 - mse: 0.5726 - val_loss: 0.7176 - val_mse: 0.7176
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5431 - mse: 0.5431 - val_loss: 0.7126 - val_mse: 0.7126
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5404 - mse: 0.5404 - val_loss: 0.7043 - val_mse: 0.7043
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5560 - mse: 0.5560 - val_loss: 0.7141 - val_mse: 0.7141
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5456 - mse: 0.5456 - val_loss: 0.7144 - val_mse: 0.7144
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5598 - mse: 0.5598 - val_loss: 0.7068 - val_mse: 0.7068
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5299 - mse: 0.5299 - val_loss: 0.7084 - val_mse: 0.7084
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5335 - mse: 0.5335 - val_loss: 0.7106 - val_mse: 0.7106
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5346 - mse: 0.5346 - val_loss: 0.7056 - val_mse: 0.7056
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5359 - mse: 0.5359 - val_loss: 0.6997 - val_mse: 0.6997
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5398 - mse: 0.5398 - val_loss: 0.7026 - val_mse: 0.7026
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5405 - mse: 0.5405 - val_loss: 0.7078 - val_mse: 0.7078
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5089 - mse: 0.5089 - val_loss: 0.7139 - val_mse: 0.7139
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5462 - mse: 0.5462 - val_loss: 0.7088 - val_mse: 0.7088
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5694 - mse: 0.5694 - val_loss: 0.7025 - val_mse: 0.7025
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5317 - mse: 0.5317 - val_loss: 0.7154 - val_mse: 0.7154
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5334 - mse: 0.5334 - val_loss: 0.7056 - val_mse: 0.7056
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5187 - mse: 0.5187 - val_loss: 0.7236 - val_mse: 0.7236
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5230 - mse: 0.5230 - val_loss: 0.7169 - val_mse: 0.7169
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5184 - mse: 0.5184 - val_loss: 0.7158 - val_mse: 0.7158
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5424 - mse: 0.5424 - val_loss: 0.7127 - val_mse: 0.7127
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5145 - mse: 0.5145 - val_loss: 0.7215 - val_mse: 0.7215
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5337 - mse: 0.5337 - val_loss: 0.7146 - val_mse: 0.7146
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5237 - mse: 0.5237 - val_loss: 0.7197 - val_mse: 0.7197
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5038 - mse: 0.5038 - val_loss: 0.7184 - val_mse: 0.7184
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5320 - mse: 0.5320 - val_loss: 0.7069 - val_mse: 0.7069
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5310 - mse: 0.5310 - val_loss: 0.7148 - val_mse: 0.7148
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5158 - mse: 0.5158 - val_loss: 0.7100 - val_mse: 0.7100
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5277 - mse: 0.5277 - val_loss: 0.7083 - val_mse: 0.7083
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5092 - mse: 0.5092 - val_loss: 0.7177 - val_mse: 0.7177
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5118 - mse: 0.5118 - val_loss: 0.7200 - val_mse: 0.7200
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4863 - mse: 0.4863 - val_loss: 0.7145 - val_mse: 0.7145
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4964 - mse: 0.4964 - val_loss: 0.7157 - val_mse: 0.7157
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# loss 체크
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7157 - mse: 0.7157
# [0.7156795263290405, 0.7156795263290405]
