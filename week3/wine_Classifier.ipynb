# %% [markdown]
# **wine_Classifier
# (KNN, Logistic Regression, Decision Tree, Random Forest)**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wine.csv')
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
y=df['Wine']
y.value_counts()
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
X=df.drop('Wine', axis=1)
X.head()
# Out:
#    Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
# 데이터를 학습용(train)과 테스트용(test)으로 나누기 (25%는 테스트 데이터)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=4)

# %%
y_train
# Out:
# 5      1
# 101    2
# 141    3
# 25     1
# 148    3
#       ..
# 87     2
# 104    2
# 129    2
# 174    3
# 122    2
# Name: Wine, Length: 133, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import warnings

# %%
scaler = StandardScaler() # 데이터를 평균 0, 표준편차 1로 바꿔주는 도구
X_train = scaler.fit_transform(X_train) # train 데이터 기준으로 평균/표준편차 계산 후 변환
X_test = scaler.transform(X_test) # train 기준으로 test 데이터 변환

knn = KNeighborsClassifier(n_neighbors=6) # train 기준으로 test 데이터 변환

knn.fit(X_train, y_train) # 이웃 6개 기준 KNN 모델 생성
y_pred = knn.predict(X_test) # 테스트 데이터로 예측 수행

scores = metrics.accuracy_score(y_test, y_pred) # 테스트 데이터로 예측 수행
print(scores) # 정확도 출력
# Out:
# 1.0

# %%
# Build a logistic regression classifier and predict

clf_lr = LogisticRegression(random_state=0, max_iter=1000)   # 로지스틱 회귀 모델 생성(반복하는 최대 횟수 지정)
clf_lr.fit(X_train, y_train)                                 # 학습용 데이터로 모델 학습(fit)

pred_lr = clf_lr.predict(X_test)                             # 테스트 데이터로 예측 수행

print("--- Logistic Regression Classifier ---")
print(accuracy_score(y_test, pred_lr))                       # 예측 정확도 출력
print(confusion_matrix(y_test, pred_lr))                     # 혼동행렬(모델이 어디서 틀렸는지 보여주는 표) 출력
# Out:
# --- Logistic Regression Classifier ---
# 0.9777777777777777
# [[15  0  0]
#  [ 0 15  0]
#  [ 0  1 14]]

# %%
# Build a decision tree classifier and predict

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.9111111111111111
# [[15  0  0]
#  [ 0 14  1]
#  [ 2  1 12]]

# %%
# Build a radom Forest classifier and predict

warnings.filterwarnings('ignore')

print ("--- Radom Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print (confusion_matrix(y_test, pred))
# Out:
# --- Radom Forest ---
# 0.9777777777777777
# [[15  0  0]
#  [ 0 14  1]
#  [ 0  0 15]]
